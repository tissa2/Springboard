# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# # Iris Data Set

# %%
#Iris Data

iris = pd.read_csv('iris.csv')

# %%
#(Q) how many data-points and features
print(iris.shape)
# Out:
# (150, 5)

# %%
#(Q) What is the colum names in our datasets?
print(iris.columns)
# Out:
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width',
#        'species'],
#       dtype='object')

# %%
#(Q) How many data points for each class are presents
# (or) How many flowers for each species are present?

iris['species'].value_counts()
# balanced-dataset vs imbalance datasets
#Iris dataset is a balanced dataset as the number of data points for every class is 50
# Out:
# setosa        50
# versicolor    50
# virginica     50
# Name: species, dtype: int64

# %% [markdown]
# # 2-D Scatter plot

# %%
# 2-D scatter plot:
# ALWAYS understand the axis: labels and scale

iris.plot(kind='scatter',x='sepal_length', y='sepal_width');
plt.show()

#cannot make much sense out it
#What if we color the points by the thier class-label/flower-type

# %%
#2-D Scatter plot with color-coding for each flower type/class
#Here 'sns' corresponds to seaborn

sns.set_style("whitegrid")
sns.FacetGrid(iris, hue="species", height=4) \
   .map(plt.scatter, "sepal_length", "sepal_width") \
   .add_legend();
plt.show()

# Notice that the blue points can be easily seperated
#from red and green by drawing a line.
# But red and green data points cannot be easily separted 
# Can we draw multiple 2-D scatter plots for each combination of features?
# How many combinations exist? 4C2=6

# %% [markdown]
# # Observations

# %% [markdown]
# 1. Using sepal_length and sepatal_with features, we can distinguidh Setosa flowers from others.
# 2. Seperating Versicolor from Viginica is much harder as they have considerable overlab.

# %% [markdown]
# Let us Try petal_length and petal_width

# %%
#2-D Scatter plot with color-coding for each flower type/class
#Here 'sns' corresponds to seaborn

sns.set_style("whitegrid")
sns.FacetGrid(iris, hue="species", height=4) \
   .map(plt.scatter, "petal_length", "petal_width") \
   .add_legend();
plt.show()

# Conclusion: petal_length and petal_width can distinguish all the tree classes
